# %%
# !pip install google-cloud-bigquery
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.8/417.8 kB 12.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.16.2 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.3 which is incompatible.
# ...

# %%
# !export GOOGLE_APPLICATION_CREDENTIALS="/Users/julia_patsiukova/Desktop/ASO/civil-hull-445017-k5-3c6805c78a6f.json"

# %%
# !echo $GOOGLE_APPLICATION_CREDENTIALS

# %%
import os
from google.cloud import bigquery

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/julia_patsiukova/Desktop/ASO/civil-hull-445017-k5-3c6805c78a6f.json"

client = bigquery.Client()

datasets = list(client.list_datasets())
for dataset in datasets:
    print(dataset.dataset_id)

# %%
from google.cloud import bigquery

client = bigquery.Client()

print(f"Authenticated with project: {client.project}")
# Out:
# Authenticated with project: civil-hull-445017-k5

# %%
from google.cloud import bigquery
import db_dtypes
print("db-dtypes is recognized!")

client = bigquery.Client()

query = """
SELECT
  *
FROM
  `patents-public-data.patents.publications`
LIMIT 10
"""

df = client.query(query).to_dataframe()
# Out:
# db-dtypes is recognized!
# /Users/julia_patsiukova/opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/table.py:2309: UserWarning: Unable to represent RANGE schema as struct using pandas ArrowDtype. Using `object` instead. To use ArrowDtype, use pandas >= 1.5 and pyarrow >= 10.0.1.
#   warnings.warn(_RANGE_PYARROW_WARNING)
# /Users/julia_patsiukova/opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/table.py:2323: UserWarning: Unable to represent RANGE schema as struct using pandas ArrowDtype. Using `object` instead. To use ArrowDtype, use pandas >= 1.5 and pyarrow >= 10.0.1.
#   warnings.warn(_RANGE_PYARROW_WARNING)
# /Users/julia_patsiukova/opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/table.py:2337: UserWarning: Unable to represent RANGE schema as struct using pandas ArrowDtype. Using `object` instead. To use ArrowDtype, use pandas >= 1.5 and pyarrow >= 10.0.1.
#   warnings.warn(_RANGE_PYARROW_WARNING)
# ...

# %%
df
# Out:
#   publication_number application_number country_code kind_code  \
# 0       HU-223109-B1      HU-P0201836-A           HU        B1
# 1       HU-223447-B1      HU-P0004790-A           HU        B1
# 2       HU-224266-B1      HU-P0003588-A           HU        B1
# 3       HU-224519-B1      HU-P0201699-A           HU        B1
# 4       HU-225784-B1      HU-P0003029-A           HU        B1
# 5       HU-225929-B1      HU-P0301303-A           HU        B1
# 6       HU-227293-B1      HU-P0800246-A           HU        B1
# 7       HU-229053-B1      HU-P0105293-A           HU        B1
# 8       HU-229058-B1      HU-P0002170-A           HU        B1
# 9       HU-229231-B1      HU-P0301272-A           HU        B1
#
#   application_kind application_number_formatted pct_number family_id  \
# 0                A                                           8178026
# 1                A                                          11004584
# ...

# %%
# !pip install --upgrade db-dtypes
# Out:
# ...
#   Using cached db_dtypes-1.4.1-py2.py3-none-any.whl (19 kB)
# ...
#   Using cached pyarrow-19.0.0.tar.gz (1.1 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyarrow (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [784 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.macosx-10.9-x86_64-cpython-39/pyarrow
#       copying pyarrow/orc.py -> build/lib.macosx-10.9-x86_64-cpython-39/pyarrow
#       copying pyarrow/conftest.py -> build/lib.macosx-10.9-x86_64-cpython-39/pyarrow
#       copying pyarrow/_generated_version.py -> build/lib.macosx-10.9-x86_64-cpython-39/pyarrow
#       copying pyarrow/benchmark.py -> build/lib.macosx-10.9-x86_64-cpython-39/pyarrow
# ...

# %%
# !brew install cmake
# # arch -arm64 brew install cmake
# !arch -arm64 brew install ninja
# !arch -arm64 brew install llvm
# !arch -arm64 brew install boost
# !arch -arm64 brew install rapidjson
# Out:
# ...
# To reinstall 3.31.5, run:
#   brew reinstall cmake
# Error: Cannot install under Rosetta 2 in ARM default prefix (/opt/homebrew)!
# To rerun under ARM use:
#     arch -arm64 brew install ...
# To install under x86_64, install Homebrew into /usr/local.

# %%
# !pip install --no-cache-dir --only-binary ":all:" --upgrade pyarrow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 8.6 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !pip install --upgrade db-dtypes
# Out:
# ...
#   Using cached db_dtypes-1.4.1-py2.py3-none-any.whl (19 kB)
# ...

# %%
import db_dtypes
print("db-dtypes is recognized!")
# Out:
# db-dtypes is recognized!
